# %% [markdown]
# ## Install ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 24.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Connect to google drive

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Train YOLOv8 to Detect BeyBlade and Hand

# %%
from ultralytics import YOLO

# %%
# !yolo train model=yolov8n.pt data= /content/gdrive/MyDrive/kecilin_test/data/data.yaml epochs=40 imgsz=640
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Test the model

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train3/weights/best.pt data=/content/gdrive/MyDrive/kecilin_test/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/gdrive/MyDrive/kecilin_test/data/test/labels.cache... 8 images, 0 backgrounds, 0 corrupt: 100% 8/8 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.27s/it]
#                    all          8         15      0.808      0.312      0.451      0.303
#               Beyblade          8          7          1       0.25      0.491       0.31
#                   Hand          8          8      0.615      0.375      0.412      0.296
# Speed: 0.2ms preprocess, 24.7ms inference, 0.0ms loss, 91.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict conf=0.5 model=/content/runs/detect/train3/weights/best.pt source=/content/gdrive/MyDrive/kecilin_test/data/train/images
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/141 /content/gdrive/MyDrive/kecilin_test/data/train/images/img_0.jpg: 384x640 1 Beyblade, 2 Hands, 97.5ms
# image 2/141 /content/gdrive/MyDrive/kecilin_test/data/train/images/img_1.jpg: 384x640 1 Beyblade, 2 Hands, 14.6ms
# image 3/141 /content/gdrive/MyDrive/kecilin_test/data/train/images/img_10.jpg: 384x640 1 Beyblade, 7.7ms
# image 4/141 /content/gdrive/MyDrive/kecilin_test/data/train/images/img_100.jpg: 384x640 2 Beyblades, 7.2ms
# image 5/141 /content/gdrive/MyDrive/kecilin_test/data/train/images/img_101.jpg: 384x640 2 Beyblades, 9.4ms
# image 6/141 /content/gdrive/MyDrive/kecilin_test/data/train/images/img_102.jpg: 384x640 2 Beyblades, 7.4ms
# image 7/141 /content/gdrive/MyDrive/kecilin_test/data/train/images/img_103.jpg: 384x640 2 Beyblades, 7.3ms
# ...

# %% [markdown]
# ## Save the best weight and result

# %%
# %cp -r '/content/runs/detect/train3/weights/best.pt' '/content/gdrive/MyDrive/kecilin_test'

# %%
# %cp -r '/content/runs/detect/predict' '/content/gdrive/MyDrive/kecilin_test'
